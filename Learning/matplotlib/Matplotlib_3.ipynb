# %%
"""
檔名：Matplotlib_3.py
功能：資料視覺化練習
學習重點：折線圖、長條圖、圓餅圖與圖表樣式設定
"""
from matplotlib import pyplot as plt
import numpy as np

# %%
# 12個月的銷售額
sale = np.array([22, 22, 17, 21, 22, 19, 21, 19, 20, 15, 24, 19])

# %%
# 12個月的利潤
profit = np.array([12, 15, 11, 17, 11, 12, 11, 10, 16, 16, 13, 11])

# %%
x = np.arange(1, 13)
# 藍色 , 線和點, 粗度2
plt.plot(x, sale, "b-o", linewidth=2)
# 紅色 , 線和點, 粗度2
plt.plot(x, profit, "r-o", linewidth=2)
# x軸 0~12 間隔1
plt.xticks(x)
# y軸 0~24 間隔1
plt.yticks(np.arange(0, max(sale) + 1, 2))
# x軸 名稱 字型大小16
plt.xlabel("Month", size=16)
# y軸 名稱 字型大小16
plt.ylabel("Million dollars", size=16)
# 圖的名稱 字型大小20
plt.title("Sales and Progit in one year", size=20)
# 顯示圖
plt.show()
