# %%
"""
檔名：bar_chart.py
功能：資料視覺化練習
學習重點：折線圖、長條圖、圓餅圖與圖表樣式設定
"""
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
xrange = np.arange(5)
yrange = np.arange(5)
width = 0.2

# %%
x = pd.Series(np.random.rand(5))
y = pd.Series(np.random.rand(5))
# 水平
# plt.barh(xrange, x, width, color="g")
# plt.barh(yrange + width, y, width, color="b")
# 垂直
plt.bar(xrange, x, width, color="g")
plt.bar(yrange + width, y, width, color="b")
plt.show()
