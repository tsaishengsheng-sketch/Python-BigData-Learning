# %%
"""
檔名：read_JSON.py
功能：開放平台資料格式練習
學習重點：XML、JSON、CSV 讀取與解析應用
"""
import json

# %%
with open("JSON_data.json", "r", encoding="utf8") as file:
    data = json.load(file)

# %%
for record in data["people"]:
    print(f"ID: {record['id']}, 姓名: {record['name']}, 國家: {record['country']}")
