# %%
"""
檔名：testCircleAndRectangle.py
功能：物件導向程式設計
學習重點：類別定義、物件實例化與封裝應用
"""
from circleFromShape import Circle
from rectangleFromShape import Rectangle

# %%
def main():
    circle = Circle(5)
    circle.__str__()
    print(f"Perimeter:{circle.getPerimeter():.2f}")
    print(f"Area:{circle.getArea():.2f}")
    print()

    rectangle= Rectangle(4, 5)
    rectangle.__str__()
    print(f"Perimeter:{rectangle.getPerimeter()}:.2f")
    print(f"Area:{rectangle.getArea()}:.2f")    
    print()

# %%
main()
