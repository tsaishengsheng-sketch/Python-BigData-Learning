# %%
"""
檔名：testQueue.py
功能：物件導向程式設計
學習重點：類別定義、物件實例化與封裝應用
"""
from queueClass import Queue

# %%
queueObj = Queue ()
for i in range (1, 6):
    queueObj.insert(i)

# %%
while not queueObj.isEmpty():
    print(f"{queueObj.delete()}", end = ' ')
