# %%
"""
檔名：queueClass.py
功能：物件導向程式設計
學習重點：類別定義、物件實例化與封裝應用
"""
class Queue:
    def __init__(self):
        self.__items = []
    
    def isEmpty(self): 
        return len(self.__items) == 0
    
    def insert(self, value):
        self.__items.insert(len(self.__items), value)
        print(f"{value} is added in queue.")
    
    def delete(self):
        if self.isEmpty():
            return 'The queue is empty.'
        else:
            return self.__items.pop(0)
    
    def getSize(self):
        return len(self.__items)
