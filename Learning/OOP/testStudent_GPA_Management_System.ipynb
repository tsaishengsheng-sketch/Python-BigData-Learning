# %%
"""
檔名：testStudent_GPA_Management_System.py
功能：物件導向程式設計
學習重點：類別定義、物件實例化與封裝應用
"""
from Student_GPA_Management_System import Gpa
def main():
    gpa0 = Gpa()
    gpa0.getGpa()
    gpa1 = Gpa('小明', 85)
    gpa1.getGpa()
    print()

    gpa2 = Gpa()
    gpa2.setName('小華')
    gpa2.setScore(72)
    gpa2.getGpa()

# %%
main()
